# %%
sum=0
n=123
while n>0:
    d=n%10
    sum+=d
    n//=10
print(sum)
# Out:
# 6

# %%
revrse=0
n=1234
i=0
while n>0:
    d=n%10
    revrse=revrse*10 + d
    i+=1
    n//=10
print(revrse)
# Out:
# 4321
